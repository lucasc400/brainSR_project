# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
os.chdir('gdrive/My Drive/Super_resolution/brainSR')

# %%
from data.image_list import create_image_list
from data.dataset import create_dataset
from data.data_loader import create_dataloader
import numpy as np
import torch
import time
import random
from collections import OrderedDict
import math
from math import log10
from utils import util, convert, metric

# %%
opt = {
    "name": "espcn_x4",
    "model": "espcn",
    "gpu_ids": [0],
    "upscale_factor":4,
    "device": "cuda",

    "datasets":
        {
            "path":
                {
                "root": "data/BrainTumour",
                "folders": ["imagesTr"]
                },
            "train":
                {
                "phase": "train",
                "batch_size": 64,
                "use_shuffle": True,
                "upscale_factor": 4,
                "scale": True,
                "no_of_images": 450,
                "n_workers": 1,
                "gaussian": dict(use=True, sigma=1, kernel_size=3, dim=2)                 
                },
            "valid":
                {
                "phase": "valid",
                "no_of_images": 34,
                "scale": True,
                "depth_padding": 1,
                "upscale_factor": 4,
                "guassian": dict(use=True, sigma=1, kernel_size=3, dim=2)
                }
    },

    
  "path": 
    {
        "root": ""
    },

  "network":
    {
        "norm_type": "batch",
#         "ngf": 64,
#         "ngb": 16,
#         "input_ngc": 1,
#         "output_ngc": 1
    },

  "train" : 
    {
        "manual_seed": 777,
        "niter": 80,
        "val_freq": 1,
        "lr": 1e-4,
        "criterion": "mse",
    },
    
  "logger": 
    {
        "print_freq": 150, # images
        "save_checkpoint_freq": 1 # iteration
    }
}

# %%
def parse(opt_path, is_train=True):
#     with open(opt_path, 'r') as f:
#         opt = json.load(f, object_pairs_hook=OrderedDict)
    opt['is_train'] = is_train

    for key, path in opt['path'].items():
        opt['path'][key] = os.path.expanduser(path)
    if is_train:
        experiments_root = os.path.join(opt['path']['root'], 'experiments', opt['name'])
        opt['path']['experiments_root'] = experiments_root
        opt['path']['options'] = experiments_root
        opt['path']['trained_models'] = os.path.join(experiments_root, 'trained_models')
        opt['path']['log'] = os.path.join(experiments_root, 'log')
    else:
        results_root = os.path.join(opt['path']['root'], 'results', opt['name'])
        opt['path']['results_root'] = results_root
        opt['path']['log'] = os.path.join(results_root, 'log')
        opt['path']['test_images'] = os.path.join(results_root, 'test_images')

    return opt

opt = parse(opt)

# %%
# seeding function for reproducibility
def seed_everything(seed):
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
SEED = 400
seed_everything(400)

# %%
training_image_list = create_image_list(opt, train=True)
valid_image_list = create_image_list(opt, valid=True)
# Out:
# 0/450 images loaded
# 50/450 images loaded
# 100/450 images loaded
# 150/450 images loaded
# 200/450 images loaded
# 250/450 images loaded
# 300/450 images loaded
# 350/450 images loaded
# 400/450 images loaded
# 0/34 images loaded

# %%
training_set = create_dataset(opt["datasets"]["train"], training_image_list)
valid_set = create_dataset(opt["datasets"]["valid"], valid_image_list)

# %%
from models.models import create_model
model = create_model(opt)
# Out:
# Model [ESPCNModel] is created.

# %%
from utils.logger import Logger
logger = Logger(opt)

# %%
def validate(val_set, val_size, model, logger, epoch, img_no):
    print('Start validation phase ...')
    val_start_time = time.time()
    model.eval() # Change to eval mode. It is important for BN layers.

    val_results = OrderedDict()
    avg_psnr = 0.0 
    avg_mse = 0.0
    for val_data in val_set:
      assert val_data['H'].shape[0] == val_data['L'].shape[0]
      batch_no = val_data['H'].shape[0]

      model.feed_data(val_data)
      model.forward()
      
      visuals = model.get_current_visuals()
      
      sr_img = visuals['super-resolution'] # uint8
      gt_img = visuals['ground-truth'] # uint8
      
      mse = model.criterion(sr_img, gt_img).item()
      psnr = 10 * log10(1 / mse)
      avg_mse += mse
      avg_psnr += psnr

    avg_mse = avg_mse / val_size
    avg_psnr = avg_psnr / val_size

    val_results['mse'] = avg_mse
    val_results['psnr'] = avg_psnr

    val_duration = time.time() - val_start_time

    model.train() # Change back to train mode.
    return val_results, val_duration

# %%
# run this model
start_time = time.time()

val_size = len(valid_set)
depth = 624

avg_train_loss_list=[]
avg_valid_loss_list=[]
lr_list = []
psnr_list = []

for iteration in range(opt['train']['niter']+1):
  train_loss=0
  val_loss=0
  for i, train_data in enumerate(training_set):
    train_start_time = time.time()
    # training
    model.feed_data(train_data)
    model.optimize_parameters(i)
    train_duration = time.time() - train_start_time
    
    train_loss += model.loss.item() # this just gets a value, whereas get_current_losses gets a dict
    if i % opt['logger']['print_freq'] == 0:
      losses = model.get_current_losses()
      logger.print_results(losses, iteration, i, train_duration, 'loss')      
        
  avg_train_loss = train_loss/len(training_set)
  avg_train_loss_list.append(avg_train_loss)

  # write training results
  if i == len(training_set)-1:
    train_results = dict(avg_train_loss = avg_train_loss,
                         learning_rate = model.optimizer.state_dict()['param_groups'][0]['lr'])
    
    logger.print_results(train_results, iteration, i, 0, 'loss')

  # validation
  if iteration % opt['train']['val_freq'] == 0:
    val_results, val_duration = validate(valid_set, val_size, model, logger, iteration, i)
    print(val_results)
    # Save to log
    logger.print_results(val_results, iteration, i, val_duration, 'val')

  # save
  if iteration % opt['logger']['save_checkpoint_freq'] == 0:
    print('Saving the model at the end of iteration %d' % (iteration))
    model.save(iteration)

  # append to lists
  lr = model.optimizer.state_dict()['param_groups'][0]['lr']
  lr_list.append(lr)
  avg_valid_loss_list.append(val_results['mse'])
  psnr_list.append(val_results['psnr'])

  # update learning rate
  if opt['train'].get('scheduler') is not None:
    if iteration % opt['train'].get('scheduler_frequency') == 0:
      model.update_learning_rate(val_results['psnr'])

  print('end of iteration ' + str(iteration))

print('lr_list:', lr_list)
print('psnr_list:', psnr_list)
print('avg_train_loss_list', avg_train_loss_list)
print('avg_valid_loss_list', avg_valid_loss_list)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2973: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# (epoch:   0, iters:        0, time: 0.038) loss: 0.03082901
# (epoch:   0, iters:      150, time: 0.033) loss: 0.00181382
# (epoch:   0, iters:      300, time: 0.033) loss: 0.00121857
# (epoch:   0, iters:      449, time: 0.000) avg_train_loss: 0.00236369 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.0007479374437346397), ('psnr', 31.35503714865684)])
# (epoch:   0, iters:      449, time: 62.177) mse: 0.00074794 psnr: 31.35503715
# Saving the model at the end of iteration 0
# end of iteration 0
# (epoch:   1, iters:        0, time: 0.036) loss: 0.00049081
# (epoch:   1, iters:      150, time: 0.032) loss: 0.00069349
# (epoch:   1, iters:      300, time: 0.033) loss: 0.00072398
# (epoch:   1, iters:      449, time: 0.000) avg_train_loss: 0.00054655 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.0005929996413589619), ('psnr', 32.36915115212756)])
# (epoch:   1, iters:      449, time: 46.994) mse: 0.00059300 psnr: 32.36915115
# Saving the model at the end of iteration 1
# end of iteration 1
# (epoch:   2, iters:        0, time: 0.035) loss: 0.00031988
# (epoch:   2, iters:      150, time: 0.033) loss: 0.00049876
# (epoch:   2, iters:      300, time: 0.032) loss: 0.00065208
# (epoch:   2, iters:      449, time: 0.000) avg_train_loss: 0.00046651 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.000551438845885808), ('psnr', 32.68725108179621)])
# (epoch:   2, iters:      449, time: 46.714) mse: 0.00055144 psnr: 32.68725108
# Saving the model at the end of iteration 2
# end of iteration 2
# (epoch:   3, iters:        0, time: 0.035) loss: 0.00028624
# (epoch:   3, iters:      150, time: 0.033) loss: 0.00051773
# (epoch:   3, iters:      300, time: 0.033) loss: 0.00052366
# (epoch:   3, iters:      449, time: 0.000) avg_train_loss: 0.00043188 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.000529067636200446), ('psnr', 32.86870697843583)])
# (epoch:   3, iters:      449, time: 46.772) mse: 0.00052907 psnr: 32.86870698
# Saving the model at the end of iteration 3
# end of iteration 3
# (epoch:   4, iters:        0, time: 0.034) loss: 0.00026279
# (epoch:   4, iters:      150, time: 0.033) loss: 0.00056264
# (epoch:   4, iters:      300, time: 0.034) loss: 0.00052948
# (epoch:   4, iters:      449, time: 0.000) avg_train_loss: 0.00041870 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.0005147493040353498), ('psnr', 32.98902577790079)])
# (epoch:   4, iters:      449, time: 46.464) mse: 0.00051475 psnr: 32.98902578
# Saving the model at the end of iteration 4
# end of iteration 4
# (epoch:   5, iters:        0, time: 0.034) loss: 0.00020328
# (epoch:   5, iters:      150, time: 0.034) loss: 0.00036946
# (epoch:   5, iters:      300, time: 0.032) loss: 0.00047557
# (epoch:   5, iters:      449, time: 0.000) avg_train_loss: 0.00040628 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.0005044795911731746), ('psnr', 33.07739662004144)])
# (epoch:   5, iters:      449, time: 45.881) mse: 0.00050448 psnr: 33.07739662
# Saving the model at the end of iteration 5
# end of iteration 5
# (epoch:   6, iters:        0, time: 0.035) loss: 0.00026268
# (epoch:   6, iters:      150, time: 0.033) loss: 0.00042405
# (epoch:   6, iters:      300, time: 0.034) loss: 0.00060479
# (epoch:   6, iters:      449, time: 0.000) avg_train_loss: 0.00039625 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.0004968073532355073), ('psnr', 33.144767537795744)])
# (epoch:   6, iters:      449, time: 45.958) mse: 0.00049681 psnr: 33.14476754
# Saving the model at the end of iteration 6
# end of iteration 6
# (epoch:   7, iters:        0, time: 0.034) loss: 0.00026752
# (epoch:   7, iters:      150, time: 0.033) loss: 0.00054609
# (epoch:   7, iters:      300, time: 0.033) loss: 0.00053499
# (epoch:   7, iters:      449, time: 0.000) avg_train_loss: 0.00039216 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.0004900410807321724), ('psnr', 33.204899331735405)])
# (epoch:   7, iters:      449, time: 45.903) mse: 0.00049004 psnr: 33.20489933
# Saving the model at the end of iteration 7
# end of iteration 7
# (epoch:   8, iters:        0, time: 0.034) loss: 0.00025572
# (epoch:   8, iters:      150, time: 0.032) loss: 0.00036393
# (epoch:   8, iters:      300, time: 0.033) loss: 0.00056725
# (epoch:   8, iters:      449, time: 0.000) avg_train_loss: 0.00038492 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.0004853630885276396), ('psnr', 33.2471801925106)])
# (epoch:   8, iters:      449, time: 46.116) mse: 0.00048536 psnr: 33.24718019
# Saving the model at the end of iteration 8
# end of iteration 8
# (epoch:   9, iters:        0, time: 0.035) loss: 0.00023601
# (epoch:   9, iters:      150, time: 0.033) loss: 0.00040132
# (epoch:   9, iters:      300, time: 0.033) loss: 0.00054809
# (epoch:   9, iters:      449, time: 0.000) avg_train_loss: 0.00037599 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.0004807083451476715), ('psnr', 33.28974091275674)])
# (epoch:   9, iters:      449, time: 46.185) mse: 0.00048071 psnr: 33.28974091
# Saving the model at the end of iteration 9
# end of iteration 9
# (epoch:  10, iters:        0, time: 0.034) loss: 0.00023159
# (epoch:  10, iters:      150, time: 0.034) loss: 0.00042274
# (epoch:  10, iters:      300, time: 0.033) loss: 0.00043947
# (epoch:  10, iters:      449, time: 0.000) avg_train_loss: 0.00036869 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.000478184746872798), ('psnr', 33.31292494358078)])
# (epoch:  10, iters:      449, time: 46.552) mse: 0.00047818 psnr: 33.31292494
# Saving the model at the end of iteration 10
# end of iteration 10
# (epoch:  11, iters:        0, time: 0.034) loss: 0.00024169
# (epoch:  11, iters:      150, time: 0.033) loss: 0.00050051
# (epoch:  11, iters:      300, time: 0.032) loss: 0.00052259
# (epoch:  11, iters:      449, time: 0.000) avg_train_loss: 0.00037747 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.00047686549934202474), ('psnr', 33.32527763312322)])
# (epoch:  11, iters:      449, time: 47.691) mse: 0.00047687 psnr: 33.32527763
# Saving the model at the end of iteration 11
# end of iteration 11
# (epoch:  12, iters:        0, time: 0.035) loss: 0.00024539
# (epoch:  12, iters:      150, time: 0.032) loss: 0.00041754
# (epoch:  12, iters:      300, time: 0.033) loss: 0.00055949
# (epoch:  12, iters:      449, time: 0.000) avg_train_loss: 0.00036179 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.0004758172855123549), ('psnr', 33.33512381552219)])
# (epoch:  12, iters:      449, time: 46.294) mse: 0.00047582 psnr: 33.33512382
# Saving the model at the end of iteration 12
# end of iteration 12
# (epoch:  13, iters:        0, time: 0.034) loss: 0.00027380
# (epoch:  13, iters:      150, time: 0.032) loss: 0.00049777
# (epoch:  13, iters:      300, time: 0.033) loss: 0.00050711
# (epoch:  13, iters:      449, time: 0.000) avg_train_loss: 0.00035834 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.0004755452836808913), ('psnr', 33.3377865243583)])
# (epoch:  13, iters:      449, time: 45.698) mse: 0.00047555 psnr: 33.33778652
# Saving the model at the end of iteration 13
# end of iteration 13
# (epoch:  14, iters:        0, time: 0.034) loss: 0.00021737
# (epoch:  14, iters:      150, time: 0.033) loss: 0.00045391
# (epoch:  14, iters:      300, time: 0.033) loss: 0.00051114
# (epoch:  14, iters:      449, time: 0.000) avg_train_loss: 0.00035308 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.0004748345253413872), ('psnr', 33.34452902518969)])
# (epoch:  14, iters:      449, time: 45.743) mse: 0.00047483 psnr: 33.34452903
# Saving the model at the end of iteration 14
# end of iteration 14
# (epoch:  15, iters:        0, time: 0.034) loss: 0.00018053
# (epoch:  15, iters:      150, time: 0.033) loss: 0.00045913
# (epoch:  15, iters:      300, time: 0.032) loss: 0.00043692
# (epoch:  15, iters:      449, time: 0.000) avg_train_loss: 0.00034869 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.00047564118679421135), ('psnr', 33.33724565119308)])
# (epoch:  15, iters:      449, time: 45.791) mse: 0.00047564 psnr: 33.33724565
# Saving the model at the end of iteration 15
# end of iteration 15
# (epoch:  16, iters:        0, time: 0.035) loss: 0.00024333
# (epoch:  16, iters:      150, time: 0.033) loss: 0.00037284
# (epoch:  16, iters:      300, time: 0.032) loss: 0.00052109
# (epoch:  16, iters:      449, time: 0.000) avg_train_loss: 0.00034513 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.0004750286307706333), ('psnr', 33.34323256607517)])
# (epoch:  16, iters:      449, time: 45.624) mse: 0.00047503 psnr: 33.34323257
# Saving the model at the end of iteration 16
# end of iteration 16
# (epoch:  17, iters:        0, time: 0.034) loss: 0.00023482
# (epoch:  17, iters:      150, time: 0.033) loss: 0.00035901
# (epoch:  17, iters:      300, time: 0.033) loss: 0.00044766
# (epoch:  17, iters:      449, time: 0.000) avg_train_loss: 0.00034082 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.00047530276317368536), ('psnr', 33.34074852618088)])
# (epoch:  17, iters:      449, time: 45.403) mse: 0.00047530 psnr: 33.34074853
# Saving the model at the end of iteration 17
# end of iteration 17
# (epoch:  18, iters:        0, time: 0.034) loss: 0.00019314
# (epoch:  18, iters:      150, time: 0.032) loss: 0.00047039
# (epoch:  18, iters:      300, time: 0.032) loss: 0.00044564
# (epoch:  18, iters:      449, time: 0.000) avg_train_loss: 0.00033949 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.0004767381041721605), ('psnr', 33.32786627544861)])
# (epoch:  18, iters:      449, time: 45.194) mse: 0.00047674 psnr: 33.32786628
# Saving the model at the end of iteration 18
# end of iteration 18
# (epoch:  19, iters:        0, time: 0.034) loss: 0.00019213
# (epoch:  19, iters:      150, time: 0.032) loss: 0.00045483
# (epoch:  19, iters:      300, time: 0.033) loss: 0.00048030
# (epoch:  19, iters:      449, time: 0.000) avg_train_loss: 0.00033601 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.0004762691635679563), ('psnr', 33.332473545287506)])
# (epoch:  19, iters:      449, time: 45.709) mse: 0.00047627 psnr: 33.33247355
# Saving the model at the end of iteration 19
# end of iteration 19
# (epoch:  20, iters:        0, time: 0.035) loss: 0.00022428
# (epoch:  20, iters:      150, time: 0.032) loss: 0.00030313
# (epoch:  20, iters:      300, time: 0.032) loss: 0.00047860
# (epoch:  20, iters:      449, time: 0.000) avg_train_loss: 0.00033277 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.00047904692217022837), ('psnr', 33.30711103113796)])
# (epoch:  20, iters:      449, time: 45.625) mse: 0.00047905 psnr: 33.30711103
# Saving the model at the end of iteration 20
# end of iteration 20
# (epoch:  21, iters:        0, time: 0.034) loss: 0.00018462
# (epoch:  21, iters:      150, time: 0.032) loss: 0.00043341
# (epoch:  21, iters:      300, time: 0.033) loss: 0.00047217
# (epoch:  21, iters:      449, time: 0.000) avg_train_loss: 0.00033350 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.0004805222672396613), ('psnr', 33.29400373512711)])
# (epoch:  21, iters:      449, time: 45.670) mse: 0.00048052 psnr: 33.29400374
# Saving the model at the end of iteration 21
# end of iteration 21
# (epoch:  22, iters:        0, time: 0.034) loss: 0.00020984
# (epoch:  22, iters:      150, time: 0.033) loss: 0.00042102
# (epoch:  22, iters:      300, time: 0.033) loss: 0.00049734
# (epoch:  22, iters:      449, time: 0.000) avg_train_loss: 0.00032921 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.00048241943809176414), ('psnr', 33.27699603476825)])
# (epoch:  22, iters:      449, time: 45.555) mse: 0.00048242 psnr: 33.27699603
# Saving the model at the end of iteration 22
# end of iteration 22
# (epoch:  23, iters:        0, time: 0.034) loss: 0.00022100
# (epoch:  23, iters:      150, time: 0.033) loss: 0.00040318
# (epoch:  23, iters:      300, time: 0.032) loss: 0.00047400
# (epoch:  23, iters:      449, time: 0.000) avg_train_loss: 0.00032478 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.00048472423890523394), ('psnr', 33.256487475593275)])
# (epoch:  23, iters:      449, time: 45.763) mse: 0.00048472 psnr: 33.25648748
# Saving the model at the end of iteration 23
# end of iteration 23
# (epoch:  24, iters:        0, time: 0.034) loss: 0.00020836
# (epoch:  24, iters:      150, time: 0.033) loss: 0.00046704
# (epoch:  24, iters:      300, time: 0.032) loss: 0.00050056
# (epoch:  24, iters:      449, time: 0.000) avg_train_loss: 0.00032414 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.0004845455602181199), ('psnr', 33.25807406770758)])
# (epoch:  24, iters:      449, time: 45.606) mse: 0.00048455 psnr: 33.25807407
# Saving the model at the end of iteration 24
# end of iteration 24
# (epoch:  25, iters:        0, time: 0.034) loss: 0.00020684
# (epoch:  25, iters:      150, time: 0.032) loss: 0.00038339
# (epoch:  25, iters:      300, time: 0.032) loss: 0.00047864
# (epoch:  25, iters:      449, time: 0.000) avg_train_loss: 0.00032348 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.0004867963580181822), ('psnr', 33.23823137649379)])
# (epoch:  25, iters:      449, time: 45.705) mse: 0.00048680 psnr: 33.23823138
# Saving the model at the end of iteration 25
# end of iteration 25
# (epoch:  26, iters:        0, time: 0.035) loss: 0.00020345
# (epoch:  26, iters:      150, time: 0.032) loss: 0.00042555
# (epoch:  26, iters:      300, time: 0.033) loss: 0.00044218
# (epoch:  26, iters:      449, time: 0.000) avg_train_loss: 0.00032362 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.0004889084563782329), ('psnr', 33.21929150878292)])
# (epoch:  26, iters:      449, time: 46.055) mse: 0.00048891 psnr: 33.21929151
# Saving the model at the end of iteration 26
# end of iteration 26
# (epoch:  27, iters:        0, time: 0.034) loss: 0.00018563
# (epoch:  27, iters:      150, time: 0.032) loss: 0.00037454
# (epoch:  27, iters:      300, time: 0.033) loss: 0.00041690
# (epoch:  27, iters:      449, time: 0.000) avg_train_loss: 0.00032077 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.0004874719460905694), ('psnr', 33.232542472682674)])
# (epoch:  27, iters:      449, time: 45.749) mse: 0.00048747 psnr: 33.23254247
# Saving the model at the end of iteration 27
# end of iteration 27
# (epoch:  28, iters:        0, time: 0.034) loss: 0.00016908
# (epoch:  28, iters:      150, time: 0.033) loss: 0.00042232
# (epoch:  28, iters:      300, time: 0.032) loss: 0.00042171
# (epoch:  28, iters:      449, time: 0.000) avg_train_loss: 0.00031760 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.0004905663672081359), ('psnr', 33.205002081199964)])
# (epoch:  28, iters:      449, time: 45.761) mse: 0.00049057 psnr: 33.20500208
# Saving the model at the end of iteration 28
# end of iteration 28
# (epoch:  29, iters:        0, time: 0.034) loss: 0.00016269
# (epoch:  29, iters:      150, time: 0.032) loss: 0.00033153
# (epoch:  29, iters:      300, time: 0.032) loss: 0.00048868
# (epoch:  29, iters:      449, time: 0.000) avg_train_loss: 0.00031652 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.0004906331159872934), ('psnr', 33.204648677306)])
# (epoch:  29, iters:      449, time: 45.661) mse: 0.00049063 psnr: 33.20464868
# Saving the model at the end of iteration 29
# end of iteration 29
# (epoch:  30, iters:        0, time: 0.034) loss: 0.00021542
# (epoch:  30, iters:      150, time: 0.033) loss: 0.00042446
# (epoch:  30, iters:      300, time: 0.032) loss: 0.00039732
# (epoch:  30, iters:      449, time: 0.000) avg_train_loss: 0.00031389 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.0004918482942123185), ('psnr', 33.19396745679499)])
# (epoch:  30, iters:      449, time: 45.679) mse: 0.00049185 psnr: 33.19396746
# Saving the model at the end of iteration 30
# end of iteration 30
# (epoch:  31, iters:        0, time: 0.034) loss: 0.00022079
# (epoch:  31, iters:      150, time: 0.032) loss: 0.00042124
# (epoch:  31, iters:      300, time: 0.032) loss: 0.00048267
# (epoch:  31, iters:      449, time: 0.000) avg_train_loss: 0.00031682 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.0004929521194700262), ('psnr', 33.18421505008092)])
# (epoch:  31, iters:      449, time: 45.561) mse: 0.00049295 psnr: 33.18421505
# Saving the model at the end of iteration 31
# end of iteration 31
# (epoch:  32, iters:        0, time: 0.035) loss: 0.00018814
# (epoch:  32, iters:      150, time: 0.033) loss: 0.00041626
# (epoch:  32, iters:      300, time: 0.032) loss: 0.00043474
# (epoch:  32, iters:      449, time: 0.000) avg_train_loss: 0.00031231 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.0004938043515293804), ('psnr', 33.176788755821406)])
# (epoch:  32, iters:      449, time: 45.767) mse: 0.00049380 psnr: 33.17678876
# Saving the model at the end of iteration 32
# end of iteration 32
# (epoch:  33, iters:        0, time: 0.034) loss: 0.00017787
# (epoch:  33, iters:      150, time: 0.033) loss: 0.00036630
# (epoch:  33, iters:      300, time: 0.032) loss: 0.00038366
# (epoch:  33, iters:      449, time: 0.000) avg_train_loss: 0.00031066 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.0004917724770219887), ('psnr', 33.194854839059715)])
# (epoch:  33, iters:      449, time: 45.801) mse: 0.00049177 psnr: 33.19485484
# Saving the model at the end of iteration 33
# end of iteration 33
# (epoch:  34, iters:        0, time: 0.035) loss: 0.00017112
# (epoch:  34, iters:      150, time: 0.032) loss: 0.00041671
# (epoch:  34, iters:      300, time: 0.032) loss: 0.00050424
# (epoch:  34, iters:      449, time: 0.000) avg_train_loss: 0.00031266 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.000491378886234837), ('psnr', 33.19854587090569)])
# (epoch:  34, iters:      449, time: 45.779) mse: 0.00049138 psnr: 33.19854587
# Saving the model at the end of iteration 34
# end of iteration 34
# (epoch:  35, iters:        0, time: 0.034) loss: 0.00023392
# (epoch:  35, iters:      150, time: 0.033) loss: 0.00035983
# (epoch:  35, iters:      300, time: 0.033) loss: 0.00048110
# (epoch:  35, iters:      449, time: 0.000) avg_train_loss: 0.00031205 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.0004925580150858663), ('psnr', 33.188075426391435)])
# (epoch:  35, iters:      449, time: 45.851) mse: 0.00049256 psnr: 33.18807543
# Saving the model at the end of iteration 35
# end of iteration 35
# (epoch:  36, iters:        0, time: 0.034) loss: 0.00018842
# (epoch:  36, iters:      150, time: 0.032) loss: 0.00038022
# (epoch:  36, iters:      300, time: 0.032) loss: 0.00044837
# (epoch:  36, iters:      449, time: 0.000) avg_train_loss: 0.00031133 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.0004951155372991172), ('psnr', 33.165530203285485)])
# (epoch:  36, iters:      449, time: 45.946) mse: 0.00049512 psnr: 33.16553020
# Saving the model at the end of iteration 36
# end of iteration 36
# (epoch:  37, iters:        0, time: 0.035) loss: 0.00018203
# (epoch:  37, iters:      150, time: 0.033) loss: 0.00036435
# (epoch:  37, iters:      300, time: 0.032) loss: 0.00051433
# (epoch:  37, iters:      449, time: 0.000) avg_train_loss: 0.00031339 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.0004946019206031718), ('psnr', 33.16987496597726)])
# (epoch:  37, iters:      449, time: 45.795) mse: 0.00049460 psnr: 33.16987497
# Saving the model at the end of iteration 37
# end of iteration 37
# (epoch:  38, iters:        0, time: 0.034) loss: 0.00020342
# (epoch:  38, iters:      150, time: 0.032) loss: 0.00041701
# (epoch:  38, iters:      300, time: 0.032) loss: 0.00042899
# (epoch:  38, iters:      449, time: 0.000) avg_train_loss: 0.00030744 learning_rate: 0.00010000
# Start validation phase ...
# OrderedDict([('mse', 0.0004948918409782517), ('psnr', 33.167216764693435)])
# (epoch:  38, iters:      449, time: 45.791) mse: 0.00049489 psnr: 33.16721676
# Saving the model at the end of iteration 38
# end of iteration 38
# (epoch:  39, iters:        0, time: 0.034) loss: 0.00022397
